# %%
# use branch multipoles https://github.com/ladosamushia/Bispectrum/tree/multipoles
include("D:/home/Bispectrum/src/powerspectrum.jl")
include("D:/home/Bispectrum/src/grid.jl")
# Out:
# grid_k

# %%
using DelimitedFiles
using Plots
# Out:
# WARNING: using Plots.gr in module Main conflicts with an existing identifier.

# %%
xyz = readdlm("C:/Users/lado/Downloads/AbacusSummit_c000_LRG_z0.5.txt")
x = xyz[:,1];
y = xyz[:,2];
z = xyz[:,3];

# %%
gr = grid_r(256, x, y, z, 1);

# %%
gk = grid_k(gr);

# %%
pk = power_spectrum(gk, 0.01, 20, 2000);

# %%
plot(pk[1,:,1])
